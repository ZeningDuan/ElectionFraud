# %% [markdown]
# ## NewsData Check After Parsing
#
# * Zening Duan & Luhang Sun, SJMC
# *  May 13, 2021

# %%
import pandas as pd

# %%
path = '/Volumes/ZeDrive1/Projects/Covid_Bot Agenda setting/News Data/Data/Fox News_data/'

# %%
data = pd.read_csv(path + 'Foxnews_data_2020_01.csv')

# %%
data
# Out:
#      Unnamed: 0                                        ArticleBody AudioUrls  \
# 0             0  Video\n\nHotel chains based in the U.S. and Un...       NaN
# 1             1  Video\n\nBEIJING (AP) — China decided Thursday...       NaN
# 2             2  Video\n\nThe central Chinese city at the cente...       NaN
# 3             3  Video\n\nU.S. equity futures are searching for...       NaN
# 4             4  Expand Menu\nFox News\n\nVideo\n\nEnlarge play...       NaN
# ..          ...                                                ...       ...
# 457         457  Video\n\nLegendary college football coach Lou ...       NaN
# 458         458  Video\n\nThe chair of the Iowa Democratic Part...       NaN
# 459         459  Video\n\nRatings for “ The Ellen DeGeneres Sho...       NaN
# 460         460  Video\n\nFox News Flash top entertainment head...       NaN
# 461         461  Video\n\nA new safe and effective oral flu vac...       NaN
#
# ...

# %%
print(len(data))
# Out:
# 462

# %%
list(set(data['Domain']))
# Out:
# ['foxnews.com', 'foxbusiness.com']

# %%
# Check length 是否和number table里的一样

# Check Date Info (DataPubublished) 是否和file name 是一致的，不一致的话，输出行数，URL, 以及实际date

# 输出domain，确认所有domain都在list中，如果没有，输出行数和实际的domain

# Check Data 是否为空值nan(float, 浮点数 in Chinese)，如是，输出行数，URL和domain

# Check Data 前50%部分有无包含指定关键词（e.g., coronavirus, covid, corona, pandemic, pneumonia, wuhan/china virus）

#Errorrows = []
#dataframe_clean = df[df[not in Errorrows]]

# Check Data_clean 是否完整，随机输出一些body和URL，人工检查

#data as our analysis units


#Expected
df_clean 
#len(df_clean) <= len(df_raw)

# %%
ERROR_all = []

def Check1(df,***):
    xxxxxx
    print(XXXX)
    
    return Errorrows_1
    
def Check2(df,***):
    xxxxxx
    print(XXXX)
    
    return Errorrows_2

def Check3(df,***):
    xxxxxx
    print(XXXX)
    
    return Errorrows_3


ERROR_all = list(set(ER1+ ER2 + ER3))

#dataframe_clean = df[df[not in Errorrows]]

# %%
data.loc[0]['ArticleBody']
# Out:
# 'Video\n\nHotel chains based in the U.S. and United Kingdom are reacting to Wuhan virus fears by waiving fees for guests who change or cancel reservations at Chinese locations.\n\nChicago-based Hyatt Hotels said Thursday morning it will waive cancellation fees for guests set to stay in areas most likely to be affected by the coronavirus outbreak that has claimed 17 lives, Reuters reported. The company has around 100 locations in the Greater China region.\n\nVirginia-based Hilton and London-based Intercontinental Hotels will do the same for customers set to stay in certain locales. Hilton has a "modification and cancellation waiver in place for all guests who plan to travel to any Hilton-branded property in China" between Jan. 21 and Feb. 8, the company told FOX Business.\n\nGuests traveling from China to a Hilton property may be eligible for cancellation and modification fees as well.\n\nIHG\'s policy applies to guests staying in mainland China, Hong Kong, Macau and Taiwan between Ja
# ...

# %%
for i in range(len(data)):
    try:
        for j in ['coronavirus', 'Wuhan virus', 'china virus' 'corona', 'covid', 'pandemic', 'pneumonia']:
            length = len(data.loc[i]['ArticleBody'])
            headlength = int(length * 0.5)
            if j not in data.loc[i]['ArticleBody'][:headlength]:
                print('not in', i)
    except:
        print('Failed', i)
        pass
# Out:
# not in 0
# not in 0
# not in 0
# not in 0
# not in 1
# not in 1
# not in 1
# not in 1
# not in 1
# not in 2
# not in 2
# not in 2
# not in 2
# not in 2
# not in 2
# not in 3
# not in 3
# not in 3
# not in 3
# not in 4
# not in 4
# not in 4
# not in 4
# not in 4
# not in 4
# not in 5
# not in 5
# not in 5
# not in 5
# not in 5
# not in 6
# not in 6
# not in 6
# not in 6
# not in 6
# not in 7
# not in 7
# not in 7
# not in 7
# not in 8
# not in 8
# not in 8
# not in 8
# not in 8
# not in 9
# not in 9
# not in 9
# not in 9
# not in 9
# not in 10
# not in 10
# not in 10
# not in 10
# not in 10
# not in 10
# not in 11
# not in 11
# not in 11
# not in 11
# not in 12
# not in 12
# not in 12
# not in 12
# not in 12
# not in 13
# not in 13
# not in 13
# not in 13
# not in 13
# not in 14
# not in 14
# not in 14
# not in 14
# not in 14
# not in 15
# not in 15
# not in 15
# not in 15
# not in 15
# not in 16
# not in 16
# not in 16
# not in 16
# not in 16
# not in 17
# not in 17
# not in 17
# ...

# %%
length = len(data.loc[0]['ArticleBody'])
headlength = int(length * 0.3)
data.loc[0]['ArticleBody'][:headlength]
# Out:
# 'Video\n\nHotel chains based in the U.S. and United Kingdom are reacting to Wuhan virus fears by waiving fees for guests who change or cancel reservations at Chinese locations.\n\nChicago-based Hyatt Hotels said Thursday morning it will waive cancellation fees for guests set to stay in areas most likely to be affected by the coronavirus outbreak that has claimed 17 lives, Reuters reported. The company has around 100 locations in the Greater China region.\n\nVirginia-based Hilton and London-based Intercontinental Hotels will do the same for customers set to stay in certain locales. Hilton has a "modification and cancellation waiver in place for all guests who plan t'

# %%
'corona' in data.loc[1]['ArticleBody'][:3000]
# Out:
# True

# %%
lens = [] 
for i in range(len(data['ArticleBody'])):
    try:
        lens.append(int(len(data['ArticleBody'][i])))
    
    except:
        print(data.loc[i])
        pass
# Out:
# Unnamed: 0                                                   19
# ArticleBody                                                 NaN
# AudioUrls                                                   NaN
# Authors                                                     NaN
# DateModified                                                NaN
# DatePublished                                               NaN
# Domain                                          foxbusiness.com
# Headline              How to prevent coronavirus from spreading
# ImageUrls                                                   NaN
# NewsUrls         https://video.foxbusiness.com/v/6126307876001/
# Prop                                                0.018064553
# VideoUrls                                                   NaN
# Name: 19, dtype: object
# Unnamed: 0                                                      44
# ArticleBody                                                    NaN
# ...

# %%
data.loc[457]
# Out:
# Unnamed: 0                                                     457
# ArticleBody      Video\n\nLegendary college football coach Lou ...
# AudioUrls                                                      NaN
# Authors                                            ['Ryan Gaydos']
# DateModified                             2020-11-19T18:57:44-05:00
# DatePublished                            2020-11-19T18:57:44-05:00
# Domain                                                 foxnews.com
# Headline         Legendary college football coach Lou Holtz, 83...
# ImageUrls        ['https://a57.foxnews.com/static.foxnews.com/f...
# NewsUrls         https://www.foxnews.com/sports/lou-holtz-tests...
# Prop                                                    0.99497163
# VideoUrls                                                      NaN
# Name: 457, dtype: object
